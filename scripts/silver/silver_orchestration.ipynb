# %% [markdown]
# # Orchestration Logic

# %%
notebooks = [
    "./silver_crm_cust_info",
    "./silver_crm_prd_info",
    "./silver_crm_sales_details",
    "./silver_erp_az12",
    "./silver_erp_loc_a101",
    "./silver_erp_px_cat_g1v2"
]

for nb in notebooks:
    print(f"Running {nb}")
    dbutils.notebook.run(nb, timeout_seconds=0)
# Out:
# Running ./silver_crm_cust_info
# Running ./silver_crm_prd_info
# Running ./silver_crm_sales_details
# Running ./silver_erp_az12
# Running ./silver_erp_loc_a101
# Running ./silver_erp_px_cat_g1v2
