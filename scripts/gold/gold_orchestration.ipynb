# %% [markdown]
# # Orchestration Logic

# %%
notebooks = [
    "./gold_dim_customers",
    "./gold_dim_products",
    "./gold_fact_sales"
]

for nb in notebooks:
    print(f"Running {nb}")
    dbutils.notebook.run(nb, timeout_seconds=0)
# Out:
# Running ./gold_dim_customers
# Running ./gold_dim_products
# Running ./gold_fact_sales
